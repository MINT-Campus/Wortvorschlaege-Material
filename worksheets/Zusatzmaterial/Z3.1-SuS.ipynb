# %%
# Hier nichts ändern!
import sys
sys.path.append("../../code")
from setup_Z3 import *
cur_modell = init_modell(zusatzblatt = True)

# %% [markdown]
# <div>
#     <img src="../../figs/cammp.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
#     <img src="../../figs/logo.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
# </div>
#
# # Zusatzblatt 1 zu Arbeitsblatt 3 | Rückfallstrategie für den allgemeinen Fall implementieren

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp;<br><br> Rückfallstrategie für Wortvorschläge </h3>
#   Ersetze im untenstehenden Codefeld die <code>None</code>, so dass ein Vorschlag gemäß der Rückfallstrategie gemacht wird. Verwende hierzu:
#   <ul>
#     <li>die Tabellen der relativen Häufigkeiten der Uni- (<code>T_Uni</code>), Bi (<code>T_Bi</code>) und Tri-Gramme (<code>T_Tri</code>).</li>
#     <li>die letzten beiden Wörter der Wortvorgeschichte bzw. das letzte Wort der Wortvorgeschichte werden in <code>w_2w_1</code> bzw. <code>w_1</code> gespeichert.</li>
#     <li>die in der Tabelle angegebenen Befehle (die <span style="color:blue">blauen</span> Begriffe zeigen an, dass hier die passende Größe ersetzt werden muss):</li>
#   </ul>
#
#   <table class="table table-bordered">
#     <thead>
#       <tr>
#         <th>Befehl</th>
#         <th>Bedeutung</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td><code>bestesWort_Uni(<span style="color:blue">w</span>)</code></td>
#         <td>generiert Wortvorschläge für die eingegebene Wortvorgeschichte w auf Basis des Uni-Gramm-Modells</td>
#       </tr>
#       <tr>
#         <td><code>bestesWort_Bi(<span style="color:blue">w</span>)</code></td>
#         <td>generiert Wortvorschläge für die eingegebene Wortvorgeschichte w auf Basis des Bi-Gramm-Modells</td>
#       </tr>
#       <tr>
#         <td><code>bestesWort_Tri(<span style="color:blue">w</span>)</code></td>
#         <td>generiert Wortvorschläge für die eingegebene Wortvorgeschichte w auf Basis des Tri-Gramm-Modells</td>
#       </tr>
#       <tr>
#         <td><code><span style="color:blue">w</span> in find(<span style="color:blue">T</span>)</code></td>
#         <td>überprüft, ob die Wortvorgeschichte w in der Tabelle T enthalten ist</td>
#       </tr>
#     </tbody>
#   </table>
#   <hr>
#   Nachdem du die <code>None</code> ersetzt hast, kannst du das Modell für verschiedene Wortvorgeschichten testen, indem du für "ich würde gerne" verschiedene andere Wortvorgeschichten einsetzt.
#   <hr>
#   <i class="fas fa-info-circle" style="font-size:20px"></i> &nbsp;
#   <a href="../../help/python_ifCondition.ipynb">Hier</a> kannst du dir nochmal die Information zu if-Anweisungen ansehen.
# </div>

# %%
# Wortvorgeschichte - hier können auch andere Wortvorgeschichten eingesetzt werden
historyStr = "ich würde gerne" # Wortvorgeschichte - hier können auch andere Wortvorgeschichten eingesetzt werden

# Hier nichts ändern!
def rueckfallstrategie(historyStr, T_Tri, T_Bi, cur_modell):
    w_last = historyStr.split()[-1].lower() # Letztes Wort der Wortvorgeschichte in Kleinbuchstabe
    w_second_to_last = historyStr.split()[-2].lower() # Vorletztes Wort der Wortvorgeschichte in Kleinbuchstabe (falls es nicht existert ist es einfach leer (""))

    # Ersetze ab hier die None
    bedingung1 = None; 
    bedingung2 = None; 
    if bedingung1:
        Vorschlag = None; 
    elif bedingung2: 
        Vorschlag = None; 
    else:
        Vorschlag = None; 

    # Hier nichts ändern!
    return Vorschlag



# Hier nichts ändern!
checkA1(rueckfallstrategie)

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
#
#
# ____
# <img src = "../../figs/CC-BY-SA.png" style="height:3em; width:auto"> </br>
# Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a> </br>
# Der verwendete Datensatz besteht aus den deutschsprachigen Texten des Korpus "What's up, Switzerland"<sup>1</sup> und den Texten der Kategorie "Belletristik" des Korpus "LIMAS"<sup>2</sup>.</br>
# Autorin: Stephanie Hofmann
# &nbsp;
#
#
# <sup>1</sup> Stark, Elisabeth; Ueberwasser, Simone; Göhring, Anne (2014-2020). Korpus "What’s up, Switzerland?". Universität Zürich. www.whatsup-switzerland.ch.</br>
# <sup>2</sup> Forschungsgruppe LIMAS (1970-1971). LIMAS-KORPUS (Linguistik und Maschinelle Sprachbearbeitung). Universität Bonn,
# Universität Regensburg.
