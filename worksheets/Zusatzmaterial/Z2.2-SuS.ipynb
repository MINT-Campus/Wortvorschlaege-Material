# %%
import sys
sys.path.append("../../code")
from setup_Z2 import *

# %% [markdown]
# <div>
#     <img src="../../figs/cammp.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
#     <img src="../../figs/logo.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
# </div>
#
# # Zusatzblatt 2 zu Arbeitsblatt 2 | Erstellung des Uni-Gramm-Modells
# Für die Bildung des Uni-Gramm-Modells müssen wir die Auftretenshäufigkeit aller einzelnen Wörter im Trainingsdatensatz bestimmen, um daraus anschließend die relativen Häufgikeiten zu berechnen. Dabei können wir ähnlich wie bei der Bestimmung der Übergangstabellen vom Bi- und Ti-Gramm-Modell vorgehen und die Auftretenshäufigkeiten der einzelnen Wörter in einer Tabelle mit dem zugehörigen Wort eintragen. Die Tabelle, die wir hierzu befüllen müssen, enthält bereits eine Zeile mit den im Text auftretenden Wörtern und eine Zeile mit der Überschrift "Häufigkeit", die aktuell noch mit nullen befüllt ist.

# %%
T1 = Tabelle(getLablesFromDataset(test_datensatz, 0))
T1

# %% [markdown]
# Diese Tabelle wollen wir mit den Häufigkeiten befüllen. Dazu können wir die Liste <code>N1</code> verwenden. Diese enthält alle auftretenden Uni-Gramme der Form <code>["Wort"]</code> im Trainingsdatensatz: <br />
#
#   <table>
#     <thead>
#       <tr><th>Uni-Gramme</th></tr>
#     </thead>
#     <tbody>
#       <tr><td>["ich"]</td></tr>
#       <tr><td>["mag"]</td></tr>
#       <tr><td>["physik"]</td></tr>
#       <tr><td>["ich"]</td></tr>
#       <tr><td>["mag"]</td></tr>
#       <tr><td>["sport"]</td></tr>
#       <tr><td>["ich"]</td></tr>
#       <tr><td>["liebe"]</td></tr>
#       <tr><td>["mathe"]</td></tr>
#       <tr><td>["jeder"]</td></tr>
#       <tr><td>["mag"]</td></tr>
#       <tr><td>["ferien"]</td></tr>
#         <tr>
#     <td colspan="3" class="cap foot">
#         <strong>Liste: N1</strong>
#     </td>
#     </tbody>
#   </table>
# <div style='text-align: center;'><strong>Liste: N1</strong></div>

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp;<br><br> a) absolute Häufigkeiten der Wörter </h3>
#   Ersetze die <code>None</code> im untenstehenden Codefeld, sodass die Tabelle T2 mit den absoluten Häufigkeiten befüllt wird. Auf die Häufigkeitseinträge der Tabelle wird mit <code>T2.at["Häufigkeit",Wort]</code> zugegriffen. Verwende dazu die Befehle <code>filtern(Eintrag, Liste)</code> und <code>len(Liste)</code>.
#   <hr>
#   <i class="fas fa-info-circle" style="font-size:20px"></i> &nbsp;
#   <a href="../../help/python_forLoopRepetition.ipynb">Hier</a> kannst du dir nochmal die Information zu for-Schleifen ansehen.
#   <hr>
#   <i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;
#   Falls du Hilfe benötigst, kannst du dich an deiner Lösung zu Aufgabe 1 auf <a href="./../AB2-SuS.ipynb">Arbeitsblatt 2</a> orientieren.
# </div>

# %%
T2 = T1.copy()

# Ersetze NaN
for Wort in getWordsFormDataset(test_datensatz):
    
    N1_gefiltert = None; 
        
    T2.at["Häufigkeit", Wort] = None; 

# Hier nichts ändern!
checkA2(T2, T1, test_datensatz)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> b) relative Häufigkeiten der Wörter - Schritt 1</h3>
#     Wir berechnen nun die relativen Häufigkeiten. Bestimme dazu zunächst die Gesamtanzahl aller Wörter im Datensatz.
#     <hr>
#     <i class="fas fa-wrench" style="font-size: 20px"></i> &nbsp;
#     Der Befehl <code>len(Liste)</code>, der die Länge einer Liste ausgibt, könnte dafür nützlich sein.
# </div>

# %%
# Berechne die Gesamtanzahl der Wörter

N = None; 

# Hier nichts ändern!
checkB2(N)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp;<br><br> c)  relative Häufigkeiten der Wörter - Schritt 2 </h3>
#     Fülle die Tabelle T3 mit den relativen Häufigkeiten. Verwende dazu die Gesamtanzahl <code>N</code> und die Einträge der Tabelle T3 <code>T3.at["Häufigkeit", Wort]</code>.
# </div>

# %%
# Hier nichts ändern!
T3 = T2.copy()
    
# Berechne die relativen Häufigkeiten

for Wort in getWordsFormDataset(test_datensatz):
    T3.at["Häufigkeit", Wort] = None; 

# Hier nichts ändern!
checkC2(T3, T2, N)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp;<br><br> d) Erproben des Modells </h3>
#     Erproben wir unser Modell! Gib ein beliebiges Wort oder mehrere beliebige Wörter für <code>None</code> ein und überprüfe, ob das Modell die Wörter mit der größten relativen Häufigkeit vorschlägt.
# </div>

# %%
bestesWort_Uni_small("None")

# %% [markdown]
# &nbsp;
#
#
# Hier geht es zurück zu [Arbeitsblatt 2](./../AB2-SuS.ipynb), wo du nun auch das Uni-Gramm-Modell, trainiert mit dem großen Trainingsdatensatz, erproben kannst.
# &nbsp;
#
# &nbsp;
#
#
# ____
# <img src = "../../figs/CC-BY-SA.png" style="height:3em; width:auto"> </br>
# Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a> </br>
# Der verwendete Datensatz besteht aus den deutschsprachigen Texten des Korpus "What's up, Switzerland"<sup>1</sup> und den Texten der Kategorie "Belletristik" des Korpus "LIMAS"<sup>2</sup>.</br>
# Autorin: Stephanie Hofmann
# &nbsp;
#
#
# <sup>1</sup> Stark, Elisabeth; Ueberwasser, Simone; Göhring, Anne (2014-2020). Korpus "What’s up, Switzerland?". Universität Zürich. www.whatsup-switzerland.ch.</br>
# <sup>2</sup> Forschungsgruppe LIMAS (1970-1971). LIMAS-KORPUS (Linguistik und Maschinelle Sprachbearbeitung). Universität Bonn,
# Universität Regensburg.
