# %%
import sys
sys.path.append("../../code")
from setup_Z1 import *

# %% [markdown]
# <div>
#     <img src="../../figs/cammp.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
#     <img src="../../figs/logo.png" style="height:7em; width:auto; float: right; margin-right: 10px;">
# </div>
#
#
# # Zusatzblatt zu Arbeitsblatt 1 | Bildung der Übergangstabelle mit einem Computerprogramm automatisieren

# %% [markdown]
# Wir wollen das Bilden der Übergangstabellen auf diesem Zusatzblatt Schritt für Schritt automatisieren. Unser Ziel ist es, dass wir das Abzählen nicht mehr per Hand übernehmen müssen, um die Übergangswahrscheinlichkeiten zu bestimmen, denn das ist bei großen Datensätzen sehr aufwendig. Dazu lassen wir uns vom Computerprogramm zunächst eine leere Tabelle ausgeben, die wir anschließend befüllen können.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> a) Tabelle laden</h3>
#   Führe das Codefeld aus, um die leere Tabelle zu laden.
# </div>

# %%
# Hier nichts ändern!
Tabelle1 = Tabelle(getLablesFromDataset(test_datensatz, 1))
Tabelle1

# %% [markdown]
# Auch in dieser Tabelle ist in der linken Spalte die Wortvorgeschichte und in der oberen Zeile das Folgewort zu finden.<br/>
# Wir haben auf dem Arbeitsblatt 1 festgestellt, dass die Betrachtung von zwei aufeinanderfolgenden Wörtern für die Bildung der Übergangswahrscheinlichkeiten und damit das Befüllen der Übergangstabelle entscheidend sind. Die zweier Wortsequenzen [Wort1, Wort2] unseres Datensatzes <span style="color:teal">"Ich mag Physik. Ich mag Sport. Ich liebe Mathe."</span> werden in der Liste `N2` gespeichert. Diese sieht wie folgt aus: <br /><br />
#
# |zweier Wortsequenzen|
# |------|
# |["ich","mag"]     |
# |["mag","physik"]     |
# |["ich","mag"]     |
# |["mag","sport"]     |
# |["ich","liebe"]     |
# |["liebe","mathe"]     |
# **Liste: N2**
# #### <span style="color: firebrick;"> Schritt 1:
# <span style="color: black;">
#
# Um die Tabelle zu befüllen, zählen wir zunächst die Auftretenshäufigkeiten der Wortsequenzen $N(\text{Wort 1},\text{ Wort 2})$. Wir wollen also erst mal nur die absoluten Häufigkeiten eintragen.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> b) Zweier-Wortsequenzen zählen</h3>
#   Befülle die erste Zeile der Tabelle Tabelle1 mit den Auftretenshäufgkeiten. Nutze dazu die Liste <code>N2</code> der Zweier-Wortsequenzen. Auf Einträge der Tabelle wird mit <code>Tabelle1.at["ich", "ich"]</code>  zugegriffen.
# </div>

# %%
# Ersetze None
Tabelle1.at["ich", "ich"] = None; 
Tabelle1.at["ich", "liebe"] = None; 
Tabelle1.at["ich", "mag"] = None; 
Tabelle1.at["ich", "mathe"] = None; 
Tabelle1.at["ich", "physik"] = None; 
Tabelle1.at["ich", "sport"] = None; 

# Hier nichts ändern!
checkB(Tabelle1)

# %% [markdown]
# Diese Zählung wollen wir nun vom Computer übernehmen lassen. Dazu schauen wir uns für den Eintrag `Tabelle1.at["ich", "mag"]` beispielhaft an, wie das funktioniert.<br />
#
#
# #### <span style="color: firebrick;"> Schritt 2:
# <span style="color: black;">
#
#
# Für den Eintrag `Tabelle1.at["ich", "mag"]` interessiert uns nur die Wortsequenz ["ich","mag"]. Alles andere aus der Tabelle der zweier Wortsequenzen können wir also entfernen.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> c) Filtern</h3>
#   Entferne alle unnötigen zweier Wortsequenzen aus der Liste der zweier Wortsequenzen <code>N2</code>. Verwende dazu den Befehl <code>filtern(E, L)</code>, der alle Einträge bis auf den Eintrag <code>E</code> aus der Liste <code>L</code> filtert. Ersetze <code>E</code> mit dem passenden Eintrag und <code>L</code> mit dem passenden Listennamen. Achte bei der Eingabe des Eintrages auf die Klammern <code>[]</code> und die Anführungszeichen <code>""</code>.
# </div>

# %%
# Ersetze NaN

N2_gefiltert = None; 

# Hier nichts ändern
checkC(N2_gefiltert)

# %% [markdown]
# #### <span style="color: firebrick;"> Schritt 3:
# <span style="color: black;">
#
#
# Wie können wir aus dieser gefilterten Liste die Auftretenshäufigkeit ablesen?

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> d) Auftretenshäufigkeit bestimmen </h3>
#   Vervollständige den Lückentext: <br>
# <center><p style="border:2px; border-style:solid; border-color:gray; padding: 1em;">Die Auftretenshäufigkeit der Wortsequenz ["ich","mag"] entspricht der  <span style="color:firebrick"><b>_____________</b></span>  unserer gefilterten Liste. </p></center>
#
# </div>

# %%
checkD()

# %% [markdown]
# #### <span style="color: firebrick;"> Schritt 4:
# <span style="color: black;">
#
# <details>
#   <summary>Erst den obigen Lückentext ausfüllen, dann hier klicken!</summary>
#     &nbsp;
#
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> c) absolute Häufigkeit einer Wortsequenz bestimmen</h3>
#   Befülle jetzt den zugehörigen Eintrag der Tabelle <code>Tabelle2</code> mit der Auftretenshäufigkeit von ["ich","mag"], indem du die Länge der gefilterten Liste <code>N2_gefiltert</code> bestimmst. Verwende dazu den Befehl <code>len(L)</code>, wobei <code>L</code> für die Liste steht, deren Länge bestimmt werden soll.
# </div>
# </details>

# %%
Tabelle2 = Tabelle(getLablesFromDataset(test_datensatz, 1))
# Ersetze None

Tabelle2.at["ich","mag"] = None; 

# Hier nichts ändern!
checkD2(Tabelle2)

# %% [markdown]
# #### <span style="color: firebrick;"> Schritt 5:
# <span style="color: black;">
#
#
# Nun wollen wir alle Einträge der Tabelle Tabelle3 befüllen. Dazu nutzen wir eine sogenannte for-Schleife

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> e) absolute Häufigkeit aller Wortsequenzen bestimmen </h3>
#   Verwende anstatt den Wörtern "ich" und "mag" nun verallgemeinert <code>Wort1</code> und <code>Wort2</code>. Orientiere dich an den Schritten 2 und 4 und ersetze die <code>None</code> im unten stehenden Codefeld, sodass die Tabelle mit den Auftretenshäufigkeiten befüllt wird.
#     <hr>
#     <i class="fas fa-wrench" style="font-size: 20px"></i> &nbsp;
#     Falls du for-Schleifen noch nicht kennst, kannst du dir<a href="../../help/python_forLoopRepetition.ipynb">&nbsp;hier</a> die Information zu for-Schleifen ansehen.
#     <hr>
#     <a href="../../help/Tipp1.1.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a>
# </div>

# %%
# Hier nichts ändern!
Tabelle3 = Tabelle(getLablesFromDataset(test_datensatz, 1))

# Ersetze NaN
for Wort1 in getWordsFormDataset(test_datensatz): #durchläuft alle Wörter des Datensatzes
    for Wort2 in getWordsFormDataset(test_datensatz): #durchläuft alle Wörter des Datensatzes

        N2_gefiltert = None; 
        Tabelle3.at[Wort1,Wort2] = None; 

# Hier nichts ändern!
checkE(Tabelle3)

# %% [markdown]
# Die Tabelle Tabelle3 enthält nun die absoluten Häufigkeiten mit der ein Wort 2 auf ein Wort 1 folgt.

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:28px"></i> &nbsp; <br><br> f) relative Häufigkeit der Wortsequenzen bestimmen </h3>
#   Bilde nun die relativen Häufigkeiten, die Übergangswahrscheinlichkeiten für die erste Zeile der Tabelle. Nutze dazu die Tabelle mit den absoluten Häufigkeiten. Auf die Einträge kannst du auch hier wieder mit <code>Tabelle3.at["Wort1","Wort2"]</code> zugreifen.
#     <hr>
#     <i class="fas fa-wrench" style="font-size: 20px"></i> &nbsp;
#     Falls du Hilfe benötigst, kannst du dir <a href="../AB1-SuS.ipynb">&nbsp;hier</a> nochmal ansehen, wie die relativen Häufigkeiten gebildet werden.
# </div>

# %%
# Hier nichts ändern!
Tabelle4 = Tabelle(getLablesFromDataset(test_datensatz, 1))

# Ersetze die NaNs
Tabelle4.at["ich","ich"]   = None; 
Tabelle4.at["ich","liebe"] = None; 
Tabelle4.at["ich","mag"]   = None; 
Tabelle4.at["ich","mathe"] = None; 
Tabelle4.at["ich","physik"]= None; 
Tabelle4.at["ich","sport"] = None; 

# Hier nichts ändern!
checkF(Tabelle4, Tabelle3)

# %% [markdown]
# Die restlichen Zeilen der Tabelle werden, sobald du das nächste Codefeld ausführst, automatisch nach obigem Schema befüllt.

# %%
# Hier nichts ändern!
row_sums = Tabelle3.sum(axis=1)

# Häufigkeiten durch Zeilensummen teilen, um Wahrscheinlichkeiten zu berechnen
Tabelle4 = Tabelle3.div(row_sums, axis=0).fillna(0)

Tabelle4

# %% [markdown]
# &nbsp;
#
#
# Hier geht es zurück zu [Arbeitsblatt 1](../AB1-SuS.ipynb).
# &nbsp;
#
# &nbsp;

# %% [markdown]
# ____
# <img src = "../../figs/CC-BY-SA.png" style="height:3em; width:auto"> </br>
# Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a> </br>
# Der verwendete Datensatz besteht aus den deutschsprachigen Texten des Korpus "What's up, Switzerland"<sup>1</sup> und den Texten der Kategorie "Belletristik" des Korpus "LIMAS"<sup>2</sup>.</br>
# Autorin: Stephanie Hofmann
# &nbsp;
#
#
# <sup>1</sup> Stark, Elisabeth; Ueberwasser, Simone; Göhring, Anne (2014-2020). Korpus "What’s up, Switzerland?". Universität Zürich. www.whatsup-switzerland.ch.</br>
# <sup>2</sup> Forschungsgruppe LIMAS (1970-1971). LIMAS-KORPUS (Linguistik und Maschinelle Sprachbearbeitung). Universität Bonn,
# Universität Regensburg.
