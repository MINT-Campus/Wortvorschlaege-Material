# %% [markdown]
# # Tipp 2
# Im untenstehenden Schaubild findest du einige zugeordnete Befehle. Nutze diese, um deine Bedingungen und Anweisungen im Codefeld zu formulieren.
# <div align="center">
# <img src="../figs/backoff_tipp.JPG"style="width: 750px;"/>
# </div>
